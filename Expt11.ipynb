# %% [markdown]
# <a href="https://colab.research.google.com/github/aditiR2508/Study-of-Categorical-Data-Analysis-using-Python/blob/main/Expt11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment - 11
# ## To study Categorical Data Analysis using Python
# ## Aditi Rathore
# ## 25070123006
# ## EnTC A1

# %%
# Nominal Data--> categories without any order
## Example:- Gender, ethnicity

# Ordinal Data

# %%
#FIRST DATASET
import pandas as pd
data = {
'Order_ID':['01','02','03','04','05','06','07','08','09','10'],
'Category':['Electronics','Clothing','Electronics','Grocery','Clothing',
            'Electronics','Grocery','Clothing','Electronics','Grocery'],
'Payment_Method':['UPI','Card','UPI','Cash','Card',
                  'UPI','Cash','Card','UPI','Cash'],
'Delivery_Type':['Express','Standard','Express','Standard','Express',
                 'Standard','Express','Standard','Express','Standard'],
'Customer_Type':['New','Returning','Returning','New','Returning',
                 'New','Returning','New','Returning','New']
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 0       01  Electronics            UPI       Express           New
# 1       02     Clothing           Card      Standard     Returning
# 2       03  Electronics            UPI       Express     Returning
# 3       04      Grocery           Cash      Standard           New
# 4       05     Clothing           Card       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 6       07      Grocery           Cash       Express     Returning
# 7       08     Clothing           Card      Standard           New
# 8       09  Electronics            UPI       Express     Returning
# 9       10      Grocery           Cash      Standard           New

# %%
# 1. Frequency Count----> counts how many orders are there in each category.
print(df['Category'].value_counts())

print()

print(df['Payment_Method'].value_counts())
# Out:
# Category
# Electronics    4
# Clothing       3
# Grocery        3
# Name: count, dtype: int64
#
# Payment_Method
# UPI     4
# Card    3
# Cash    3
# Name: count, dtype: int64

# %%
# 2. Unique Values--->displays all unique categories
print(df['Category'].unique())

print()

print(df['Delivery_Type'].unique())
# Out:
# ['Electronics' 'Clothing' 'Grocery']
#
# ['Express' 'Standard']

# %%
# 3. Number of unique values--->how many unique values are there
print(df['Category'].nunique())
# Out:
# 3

# %%
# 4. Cross tabulation---->category vs. payment method--->relationship between two variables
print(pd.crosstab(df['Category'], df['Payment_Method']))

print()

print(pd.crosstab(df['Delivery_Type'], df['Customer_Type']))
# Out:
# Payment_Method  Card  Cash  UPI
# Category
# Clothing           3     0    0
# Electronics        0     0    4
# Grocery            0     3    0
#
# Customer_Type  New  Returning
# Delivery_Type
# Express          1          4
# Standard         4          1

# %%
# 5. Percentage distribution--->tells about the weightage of every quantity in terms of its percentage
print(df['Category'].value_counts(normalize=True)*100)
# Out:
# Category
# Electronics    40.0
# Clothing       30.0
# Grocery        30.0
# Name: proportion, dtype: float64

# %%
# 6. Filtering Data--->to access specific data containing common variable
### Example: orders from electronics category

electronics_orders = df[df['Category']=='Electronics']
print(electronics_orders)
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 0       01  Electronics            UPI       Express           New
# 2       03  Electronics            UPI       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 8       09  Electronics            UPI       Express     Returning

# %%
# 7. Grouping---->combining--->orders by category and payment method
print(df.groupby('Category')['Payment_Method'].value_counts())
# Out:
# Category     Payment_Method
# Clothing     Card              3
# Electronics  UPI               4
# Grocery      Cash              3
# Name: count, dtype: int64

# %%
# 8. Sorting Data--->arranges data in ascending and alphabetical order
sorted_df = df.sort_values(by='Category')
print(sorted_df)
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 1       02     Clothing           Card      Standard     Returning
# 4       05     Clothing           Card       Express     Returning
# 7       08     Clothing           Card      Standard           New
# 0       01  Electronics            UPI       Express           New
# 2       03  Electronics            UPI       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 8       09  Electronics            UPI       Express     Returning
# 3       04      Grocery           Cash      Standard           New
# 6       07      Grocery           Cash       Express     Returning
# 9       10      Grocery           Cash      Standard           New

# %%
# SECOND DATASET
import pandas as pd

df = pd.read_csv("/content/Expt11.csv")
print(df.head())
# Out:
#   Student  Gender Department Grade
# 0      S1    Male        CSE     A
# 1      S2  Female         IT     B
# 2      S3  Female        CSE     A
# 3      S4    Male        ECE     C
# 4      S5    Male         IT     B

# %%
# 1. Count students in each grade
print("Grade Freuency:")
print(df['Grade'].value_counts())
# Out:
# Grade Freuency:
# Grade
# B    24
# A    22
# C    14
# Name: count, dtype: int64

# %%
# 2. Percentage Distribution of Grades
print("Grade Percentage:")
print(df['Grade'].value_counts(normalize=True)*100)
# Out:
# Grade Percentage:
# Grade
# B    40.000000
# A    36.666667
# C    23.333333
# Name: proportion, dtype: float64

# %%
# 3. Number of students in each department
print("Number of Students, Department-wise:")
print(df['Department'].value_counts())
# Out:
# Number of Students, Department-wise:
# Department
# CSE           20
# IT            18
# ECE           11
# Mechanical    11
# Name: count, dtype: int64

# %%
# 4. Gender distribution
print("Gender count:")
print(df['Gender'].value_counts())
# Out:
# Gender count:
# Gender
# Male      30
# Female    30
# Name: count, dtype: int64

# %%
# 5. Gender vs. Grade Analysis
print("Gender vs. Grade:")
print(pd.crosstab(df['Gender'], df['Grade']))

print()

print("Department vs. Gender:")
print(pd.crosstab(df['Department'], df['Gender']))
# Out:
# Gender vs. Grade:
# Grade    A   B  C
# Gender
# Female  14  11  5
# Male     8  13  9
#
# Department vs. Gender:
# Gender      Female  Male
# Department
# CSE             12     8
# ECE              5     6
# IT               9     9
# Mechanical       4     7

# %%
# 6. Grouping Data
print(df.groupby('Department')['Grade'].value_counts())
# Out:
# Department  Grade
# CSE         A        13
#             B         4
#             C         3
# ECE         B         5
#             C         4
#             A         2
# IT          B         8
#             A         7
#             C         3
# Mechanical  B         7
#             C         4
# Name: count, dtype: int64
